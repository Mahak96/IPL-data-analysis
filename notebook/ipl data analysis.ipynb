# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
batsman_df=pd.read_csv('../data/Batsman_info.csv')

# %%
batsman_df.head()
# Out:
#    Unnamed: 0         batsmen      R      B      M  fours  sixes       SR  \
# 0           0  A Ashish Reddy  280.0  193.0  262.0   17.0   14.0  3163.89
# 1           1      A Chandila    4.0    7.0   16.0    0.0    0.0    66.66
# 2           2        A Chopra   53.0   71.0    0.0    7.0    0.0   370.36
# 3           3     A Choudhary   25.0   20.0   30.0    1.0    1.0   491.66
# 4           4     A Dananjaya    4.0    5.0    0.0    0.0    0.0    80.00
#
#    boundary_contribution  100s  50s  times_played    average
# 0               2.175375   0.0  0.0            23  12.173913
# 1               0.000000   0.0  0.0             2   2.000000
# 2               0.460664   0.0  0.0             6   8.833333
# 3               0.233333   0.0  0.0             3   8.333333
# 4               0.000000   0.0  0.0             1   4.000000

# %%
batting_df=pd.read_csv('../data/ipl_batting.csv')

# %%
batting_df.head()
# Out:
#   match_no          team_1               team_2        batsmen  \
# 0        1  Mumbai Indians  Chennai Super Kings  ST Jayasuriya
# 1        1  Mumbai Indians  Chennai Super Kings   SR Tendulkar
# 2        1  Mumbai Indians  Chennai Super Kings       S Dhawan
# 3        1  Mumbai Indians  Chennai Super Kings      JP Duminy
# 4        1  Mumbai Indians  Chennai Super Kings       DJ Bravo
#
#                 wicket_status     R     B    M  fours  sixes      SR  \
# 0         c Hayden b Thushara  26.0  20.0  0.0    5.0    0.0  130.00
# 1                     not out  59.0  49.0  0.0    7.0    0.0  120.40
# 2              c Dhoni b Gony  22.0  21.0  0.0    2.0    0.0  104.76
# 3                  c & b Gony   9.0   7.0  0.0    1.0    0.0  128.57
# 4  c Hayden b Joginder Sharma   5.0   4.0  0.0    1.0    0.0  125.00
#
#     special_role dismissal_mode      bowler_name     fielder  \
# 0  normal player         caught         Thushara      Hayden
# ...

# %%
deliveries_df=pd.read_csv('../data/ipl_deliveries.csv')

# %%
deliveries_df.head()
# Out:
#      Match_id      Innings  Over  Delivery    Batsman         Bowler  \
# 0  2016043001  1st innings     1       0.1  DA Warner  KW Richardson
# 1  2016043001  1st innings     1       0.2  DA Warner  KW Richardson
# 2  2016043001  1st innings     1       0.3  DA Warner  KW Richardson
# 3  2016043001  1st innings     1       0.4   S Dhawan  KW Richardson
# 4  2016043001  1st innings     1       0.5   S Dhawan  KW Richardson
#
#   non_striker  runs_batsman  runs_extras extras_type  Runs_total player_out  \
# 0    S Dhawan             0            0         NaN           0        NaN
# 1    S Dhawan             4            0         NaN           4        NaN
# 2    S Dhawan             1            0         NaN           1        NaN
# 3   DA Warner             0            0         NaN           0        NaN
# 4   DA Warner             0            0         NaN           0        NaN
#
#   mode_of_dismissal fielders_involved
# 0               NaN               NaN
# ...

# %% [markdown]
# matches_df=pd.read_csv('../data/ipl_matches.csv')

# %%
matches_df=pd.read_csv('../data/ipl_matches.csv')

# %%
matches_df.head()
# Out:
#    match_date                Ground                       Team 1  \
# 0  2008-04-18  Bengaluru, Bangalore  Royal Challengers Bangalore
# 1  2008-04-19    Mohali, Chandigarh              Kings XI Punjab
# 2  2008-04-19                 Delhi               Delhi Capitals
# 3  2008-04-20               Kolkata        Kolkata Knight Riders
# 4  2008-04-20                Mumbai               Mumbai Indians
#
#                         Team 2                       Winner  year  month  day  \
# 0        Kolkata Knight Riders        Kolkata Knight Riders  2008      4   18
# 1          Chennai Super Kings          Chennai Super Kings  2008      4   19
# 2             Rajasthan Royals               Delhi Capitals  2008      4   19
# 3              Deccan Chargers        Kolkata Knight Riders  2008      4   20
# 4  Royal Challengers Bangalore  Royal Challengers Bangalore  2008      4   20
#
#   win_mode  margin                  toss_winner toss_decision  match_no
# ...

# %%
info_df=pd.read_csv('../data/team_info.csv')

# %%
info_df.head()
# Out:
#    Unnamed: 0                 Team  Win+Toss  Toss  %(win+toss)      %toss  \
# 0           0  Chennai Super Kings        57    89    64.044944  53.614458
# 1          11      Deccan Chargers        19    43    44.186047  56.578947
# 2          19       Delhi Capitals        41    90    45.555556  50.561798
# 3          29        Gujarat Lions        10    15    66.666667  50.000000
# 4          36      Kings XI Punjab        34    80    42.500000  45.714286
#
#    total_matches  %(win+toss)/total  Win  Lost
# 0            166          34.337349   32   134
# 1             76          25.000000   24    52
# 2            178          23.033708   49   129
# 3             30          33.333333    5    25
# 4            175          19.428571   46   129

# %%
matches_df.dtypes
# Out:
# match_date        object
# Ground            object
# Team 1            object
# Team 2            object
# Winner            object
# year               int64
# month              int64
# day                int64
# win_mode          object
# margin           float64
# toss_winner       object
# toss_decision     object
# match_no           int64
# dtype: object

# %%
date=matches_df.match_date
key=[]
visited=[]
for i in date:
      if i in visited:
         number=visited.count(i)
         temp=i.split('-')
         temp1=temp[0]+temp[1]+temp[2]+'0'+str(number+1)
         visited.append(i)
         key.append(temp1)
      else: 
          temp=i.split('-')
          temp1=temp[0]+temp[1]+temp[2]+'01'
          key.append(temp1)
          visited.append(i)

# %%
matches_df['match_key']=key

# %% [markdown]
# matches_df.head()

# %%
matches_df['Team 1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Mumbai Indians', 'Rajasthan Royals',
#        'Deccan Chargers', 'Chennai Super Kings', 'Kochi Tuskers Kerala',
#        'Pune Warriors', 'Sunrisers Hyderabad', 'Gujarat Lions',
#        'Rising Pune Supergiant'], dtype=object)

# %%
matches_df['Team 2'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Deccan Chargers', 'Royal Challengers Bangalore',
#        'Kings XI Punjab', 'Delhi Capitals', 'Mumbai Indians',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiant', 'Gujarat Lions'], dtype=object)

# %%
matches_df['toss_winner'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Chennai Super Kings',
#        'Rajasthan Royals', 'Deccan Chargers', 'Mumbai Indians',
#        'Kings XI Punjab', 'Kolkata Knight Riders', 'Delhi Capitals',
#        'no toss', 'Kochi Tuskers Kerala', 'Pune Warriors',
#        'Sunrisers Hyderabad', 'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant'], dtype=object)

# %%
matches_df['toss_winner'].replace(to_replace='Rising Pune Supergiants',value='Rising Pune Supergiant',inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13488\3769007954.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   matches_df['toss_winner'].replace(to_replace='Rising Pune Supergiants',value='Rising Pune Supergiant',inplace=True)

# %%
matches_df['toss_winner'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Chennai Super Kings',
#        'Rajasthan Royals', 'Deccan Chargers', 'Mumbai Indians',
#        'Kings XI Punjab', 'Kolkata Knight Riders', 'Delhi Capitals',
#        'no toss', 'Kochi Tuskers Kerala', 'Pune Warriors',
#        'Sunrisers Hyderabad', 'Gujarat Lions', 'Rising Pune Supergiant'],
#       dtype=object)

# %%
Team_1=matches_df['Team 1'].groupby(matches_df['Team 1']).agg('count')

# %%
Team_1
# Out:
# Team 1
# Chennai Super Kings             91
# Deccan Chargers                 39
# Delhi Capitals                  92
# Gujarat Lions                   16
# Kings XI Punjab                 87
# Kochi Tuskers Kerala             7
# Kolkata Knight Riders           87
# Mumbai Indians                  87
# Pune Warriors                   23
# Rajasthan Royals                66
# Rising Pune Supergiant          14
# Royal Challengers Bangalore    101
# Sunrisers Hyderabad             53
# Name: Team 1, dtype: int64

# %%
Team_2=matches_df['Team 2'].groupby(matches_df['Team 2']).agg('count')

# %%
Team_2
# Out:
# Team 2
# Chennai Super Kings             75
# Deccan Chargers                 37
# Delhi Capitals                  86
# Gujarat Lions                   14
# Kings XI Punjab                 88
# Kochi Tuskers Kerala             7
# Kolkata Knight Riders           94
# Mumbai Indians                 101
# Pune Warriors                   23
# Rajasthan Royals                84
# Rising Pune Supergiant          16
# Royal Challengers Bangalore     82
# Sunrisers Hyderabad             56
# Name: Team 2, dtype: int64

# %%
total_matches=Team_1+Team_2

# %%
total_matches
# Out:
# Team 1
# Chennai Super Kings            166
# Deccan Chargers                 76
# Delhi Capitals                 178
# Gujarat Lions                   30
# Kings XI Punjab                175
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          181
# Mumbai Indians                 188
# Pune Warriors                   46
# Rajasthan Royals               150
# Rising Pune Supergiant          30
# Royal Challengers Bangalore    183
# Sunrisers Hyderabad            109
# dtype: int64

# %%
toss_winner=matches_df['toss_winner'].groupby(matches_df['toss_winner']).agg('count')

# %%
toss_winner
# Out:
# toss_winner
# Chennai Super Kings            89
# Deccan Chargers                43
# Delhi Capitals                 90
# Gujarat Lions                  15
# Kings XI Punjab                80
# Kochi Tuskers Kerala            8
# Kolkata Knight Riders          92
# Mumbai Indians                 98
# Pune Warriors                  20
# Rajasthan Royals               80
# Rising Pune Supergiant         13
# Royal Challengers Bangalore    82
# Sunrisers Hyderabad            46
# no toss                         7
# Name: toss_winner, dtype: int64

# %%
percentage_winning=(toss_winner/total_matches)*100

# %%
percentage_winning
# Out:
# Chennai Super Kings            53.614458
# Deccan Chargers                56.578947
# Delhi Capitals                 50.561798
# Gujarat Lions                  50.000000
# Kings XI Punjab                45.714286
# Kochi Tuskers Kerala           57.142857
# Kolkata Knight Riders          50.828729
# Mumbai Indians                 52.127660
# Pune Warriors                  43.478261
# Rajasthan Royals               53.333333
# Rising Pune Supergiant         43.333333
# Royal Challengers Bangalore    44.808743
# Sunrisers Hyderabad            42.201835
# no toss                              NaN
# dtype: float64

# %%
match_winner=matches_df['Winner'].groupby(matches_df['Winner']).agg('count')

# %%
match_winner
# Out:
# Winner
# Chennai Super Kings            100
# Deccan Chargers                 29
# Delhi Capitals                  76
# Gujarat Lions                   13
# Kings XI Punjab                 80
# Kochi Tuskers Kerala             6
# Kolkata Knight Riders           91
# Match                            2
# Mumbai Indians                 107
# Pune Warriors                   12
# Rajasthan Royals                73
# Rising Pune Supergiant          15
# Royal Challengers Bangalore     83
# Sunrisers Hyderabad             57
# abandoned                        6
# no result                        5
# tied                             8
# Name: Winner, dtype: int64

# %%
toss_match_winner=matches_df['Team 1'].groupby([matches_df['Winner'],matches_df['toss_winner']]).agg('count')

# %%
toss_match_winner
# Out:
# Winner               toss_winner
# Chennai Super Kings  Chennai Super Kings            57
#                      Deccan Chargers                 2
#                      Delhi Capitals                  7
#                      Kings XI Punjab                 3
#                      Kolkata Knight Riders           6
#                                                     ..
# tied                 Kings XI Punjab                 1
#                      Kolkata Knight Riders           1
#                      Mumbai Indians                  1
#                      Rajasthan Royals                1
#                      Royal Challengers Bangalore     2
# Name: Team 1, Length: 125, dtype: int64

# %%
temp=toss_match_winner.reset_index()

# %%
temp
# Out:
#                   Winner                  toss_winner  Team 1
# 0    Chennai Super Kings          Chennai Super Kings      57
# 1    Chennai Super Kings              Deccan Chargers       2
# 2    Chennai Super Kings               Delhi Capitals       7
# 3    Chennai Super Kings              Kings XI Punjab       3
# 4    Chennai Super Kings        Kolkata Knight Riders       6
# ..                   ...                          ...     ...
# 120                 tied              Kings XI Punjab       1
# 121                 tied        Kolkata Knight Riders       1
# 122                 tied               Mumbai Indians       1
# 123                 tied             Rajasthan Royals       1
# 124                 tied  Royal Challengers Bangalore       2
#
# [125 rows x 3 columns]

# %%
df=temp.loc[temp['Winner']==temp['toss_winner']]
df
# Out:
#                           Winner                  toss_winner  Team 1
# 0            Chennai Super Kings          Chennai Super Kings      57
# 11               Deccan Chargers              Deccan Chargers      19
# 19                Delhi Capitals               Delhi Capitals      41
# 29                 Gujarat Lions                Gujarat Lions      10
# 36               Kings XI Punjab              Kings XI Punjab      34
# 44          Kochi Tuskers Kerala         Kochi Tuskers Kerala       4
# 50         Kolkata Knight Riders        Kolkata Knight Riders      53
# 63                Mumbai Indians               Mumbai Indians      55
# 75                 Pune Warriors                Pune Warriors       3
# 84              Rajasthan Royals             Rajasthan Royals      41
# 89        Rising Pune Supergiant       Rising Pune Supergiant       8
# 103  Royal Challengers Bangalore  Royal Challengers Bangalore      40
# ...

# %%
dif=toss_winner.to_numpy()

dif=np.delete(dif,13)
print(dif)
# Out:
# [89 43 90 15 80  8 92 98 20 80 13 82 46]

# %%
df['Team']=dif
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13488\4217512933.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Team']=dif

# %%
df=df.drop(columns=['Winner'])

# %%
df.columns=['Team','Win+Toss','Toss']

# %%
tem= percentage_winning.to_numpy()

# %%
df['%(win+toss)']=(df['Win+Toss']/df['Toss'])*100

# %%
tem=percentage_winning.to_numpy()

toss=np.delete(tem,13)

# %%
df['total_matches']=total_matches.to_numpy()

# %%
df['%(win+toss)/total']=(df['Win+Toss']/df['total_matches'])*100

# %%
df.head()
# Out:
#                    Team  Win+Toss  Toss  %(win+toss)  total_matches  \
# 0   Chennai Super Kings        57    89    64.044944            166
# 11      Deccan Chargers        19    43    44.186047             76
# 19       Delhi Capitals        41    90    45.555556            178
# 29        Gujarat Lions        10    15    66.666667             30
# 36      Kings XI Punjab        34    80    42.500000            175
#
#     %(win+toss)/total
# 0           34.337349
# 11          25.000000
# 19          23.033708
# 29          33.333333
# 36          19.428571

# %%
ax = sns.barplot(x=df['Team'], y = df['Win+Toss']).set_xticklabels(df['Team'], rotation=90)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13488\2914287853.py:1: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax = sns.barplot(x=df['Team'], y = df['Win+Toss']).set_xticklabels(df['Team'], rotation=90)

# %%
ax = sns.barplot(x=df['Team'], y = df['%(win+toss)/total']).set_xticklabels(df['Team'], rotation=90)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13488\2246181755.py:1: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax = sns.barplot(x=df['Team'], y = df['%(win+toss)/total']).set_xticklabels(df['Team'], rotation=90)

# %% [markdown]
# Question 3
# 1.) list the names of the top 10 batsmen by total runs accumulated across all the seasons
# 2.) the output shoukld be stored in a list

# %%
batsmen=batting_df['R'].groupby(batting_df['batsmen']).sum()

# %%
batsman_df.batsmen.reset_index()
# Out:
#      index         batsmen
# 0        0  A Ashish Reddy
# 1        1      A Chandila
# 2        2        A Chopra
# 3        3     A Choudhary
# 4        4     A Dananjaya
# ..     ...             ...
# 513    513     YV Takawale
# 514    514   Yashpal Singh
# 515    515     Younis Khan
# 516    516    Yuvraj Singh
# 517    517          Z Khan
#
# [518 rows x 2 columns]

# %%
batsman_df.sort_values(['R'],axis=0,ascending=False,inplace=True)

# %%
batsman_df.head()
# Out:
#      Unnamed: 0    batsmen       R       B       M  fours  sixes        SR  \
# 487         487    V Kohli  5412.0  4112.0  4225.0  480.0  190.0  20030.77
# 424         424   SK Raina  5368.0  3915.0  3645.0  493.0  194.0  22585.81
# 366         366  RG Sharma  4898.0  3744.0  3665.0  431.0  194.0  20495.90
# 113         113  DA Warner  4706.0  3305.0  3929.0  458.0  181.0  15653.18
# 393         393   S Dhawan  4579.0  3669.0  3987.0  524.0   96.0  17638.07
#
#      boundary_contribution  100s   50s  times_played    average
# 487              18.559622   5.0  36.0           169  32.023669
# 424              20.137846   1.0  38.0           189  28.402116
# 366              18.349718   1.0  36.0           183  26.765027
# 113              15.215273   4.0  44.0           126  37.349206
# 393              19.483546   0.0  37.0           158  28.981013

# %% [markdown]
# question 4
# visualise the runs made vs balls faced in a joint plot . you should do thid all batsmen who batted in ipl season 2017

# %%
print(batting_df)
df=batting_df
dt=df.match_date
col=list()
for i in dt:
    i= str(i)
    temp=i.split('-')
    col.append(temp[0])
df['year']=col
# Out:
#         match_no               team_1               team_2        batsmen  \
# 0              1       Mumbai Indians  Chennai Super Kings  ST Jayasuriya
# 1              1       Mumbai Indians  Chennai Super Kings   SR Tendulkar
# 2              1       Mumbai Indians  Chennai Super Kings       S Dhawan
# 3              1       Mumbai Indians  Chennai Super Kings      JP Duminy
# 4              1       Mumbai Indians  Chennai Super Kings       DJ Bravo
# ...          ...                  ...                  ...            ...
# 11541  Final (N)  Chennai Super Kings     Rajasthan Royals      YK Pathan
# 11542  Final (N)  Chennai Super Kings     Rajasthan Royals         M Kaif
# 11543  Final (N)  Chennai Super Kings     Rajasthan Royals      RA Jadeja
# 11544  Final (N)  Chennai Super Kings     Rajasthan Royals       SK Warne
# 11545  Final (N)  Chennai Super Kings     Rajasthan Royals  Sohail Tanvir
#
#                     wicket_status     R     B    M  fours  sixes      SR  \
# ...

# %%
df.head()
# Out:
#   match_no          team_1               team_2        batsmen  \
# 0        1  Mumbai Indians  Chennai Super Kings  ST Jayasuriya
# 1        1  Mumbai Indians  Chennai Super Kings   SR Tendulkar
# 2        1  Mumbai Indians  Chennai Super Kings       S Dhawan
# 3        1  Mumbai Indians  Chennai Super Kings      JP Duminy
# 4        1  Mumbai Indians  Chennai Super Kings       DJ Bravo
#
#                 wicket_status     R     B    M  fours  sixes      SR  \
# 0         c Hayden b Thushara  26.0  20.0  0.0    5.0    0.0  130.00
# 1                     not out  59.0  49.0  0.0    7.0    0.0  120.40
# 2              c Dhoni b Gony  22.0  21.0  0.0    2.0    0.0  104.76
# 3                  c & b Gony   9.0   7.0  0.0    1.0    0.0  128.57
# 4  c Hayden b Joginder Sharma   5.0   4.0  0.0    1.0    0.0  125.00
#
#     special_role dismissal_mode      bowler_name     fielder  \
# 0  normal player         caught         Thushara      Hayden
# ...

# %%
df=df[df['year']=='2017']

# %%
df.head()
# Out:
#      match_no               team_1                       team_2       batsmen  \
# 6962        1  Sunrisers Hyderabad  Royal Challengers Bangalore     DA Warner
# 6963        1  Sunrisers Hyderabad  Royal Challengers Bangalore      S Dhawan
# 6964        1  Sunrisers Hyderabad  Royal Challengers Bangalore  MC Henriques
# 6965        1  Sunrisers Hyderabad  Royal Challengers Bangalore  Yuvraj Singh
# 6966        1  Sunrisers Hyderabad  Royal Challengers Bangalore      DJ Hooda
#
#                     wicket_status     R     B     M  fours  sixes      SR  \
# 6962  c Mandeep Singh b Choudhary  14.0   8.0  10.0    2.0    1.0  175.00
# 6963        c Sachin Baby b Binny  40.0  31.0  51.0    5.0    0.0  129.03
# 6964       c Sachin Baby b Chahal  52.0  37.0  67.0    3.0    2.0  140.54
# 6965                      b Mills  62.0  27.0  49.0    7.0    3.0  229.62
# 6966                      not out  16.0  12.0  29.0    0.0    1.0  133.33
#
# ...

# %%
sns.jointplot(x='R',y='B',data=df)

# %% [markdown]
# question 5
# 1 create a new calculated column called boundary_contribution.it is called as:(total runs made in 4s+6s)/(total runs scored)
# 2 create a scatter-plot between boundary_contribution and strike_rate where each dot represents an innings by a batsman
# 3 aggregate boundary_contribution by player and list down top 10 players by boundary_contribution across all seasons

# %%
batting_df['boundary_contribution']=(batting_df['fours']+batting_df['sixes'])/batting_df['R']

# %%
batting_df.head()
# Out:
#   match_no          team_1               team_2        batsmen  \
# 0        1  Mumbai Indians  Chennai Super Kings  ST Jayasuriya
# 1        1  Mumbai Indians  Chennai Super Kings   SR Tendulkar
# 2        1  Mumbai Indians  Chennai Super Kings       S Dhawan
# 3        1  Mumbai Indians  Chennai Super Kings      JP Duminy
# 4        1  Mumbai Indians  Chennai Super Kings       DJ Bravo
#
#                 wicket_status     R     B    M  fours  sixes      SR  \
# 0         c Hayden b Thushara  26.0  20.0  0.0    5.0    0.0  130.00
# 1                     not out  59.0  49.0  0.0    7.0    0.0  120.40
# 2              c Dhoni b Gony  22.0  21.0  0.0    2.0    0.0  104.76
# 3                  c & b Gony   9.0   7.0  0.0    1.0    0.0  128.57
# 4  c Hayden b Joginder Sharma   5.0   4.0  0.0    1.0    0.0  125.00
#
#     special_role dismissal_mode      bowler_name     fielder  \
# 0  normal player         caught         Thushara      Hayden
# ...

# %%
ax=sns.scatterplot(x='boundary_contribution',y='SR',data=batting_df)

# %%
boundary_contribution=batting_df['boundary_contribution'].groupby(batting_df['batsmen']).sum()

# %%
boundary_contribution=boundary_contribution.reset_index()

# %%
boundary_contribution.sort_values(['boundary_contribution'],axis=0,ascending=False,inplace=True)

# %%
boundary_contribution.head()
# Out:
#         batsmen  boundary_contribution
# 424    SK Raina              20.137846
# 385  RV Uthappa              19.642338
# 393    S Dhawan              19.483546
# 487     V Kohli              18.559622
# 366   RG Sharma              18.349718

# %%
ax = sns.barplot(x=boundary_contribution['batsmen'].head(10), 
                 y=boundary_contribution['boundary_contribution'].head(10),
                color='red')

# Set x-axis labels
ax.set_xticklabels(boundary_contribution['batsmen'].head(10), rotation=90)

plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13488\1804826347.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(boundary_contribution['batsmen'].head(10), rotation=90)
